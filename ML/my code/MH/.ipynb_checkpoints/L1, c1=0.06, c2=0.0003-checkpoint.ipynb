# %% [markdown]
# # Intro

# %%
# !pip install tensorflow==2.0.0-rc1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math
print(tf.__version__)
# Out:
# 2.0.0-rc1

# %%
def coth(a):
    if a>0: return (1+tf.math.exp(-2*a))/(1-tf.math.exp(-2*a))
    if a<0: return (tf.math.exp(2*a)+1)/(tf.math.exp(2*a)-1)
    if a==0: return 0

def tanh(a):
    if a>0: return (1-tf.math.exp(-2*a))/(1+tf.math.exp(-2*a))
    if a<0: return (tf.math.exp(2*a)-1)/(tf.math.exp(2*a)+1)
    if a==0: return 0

# %%
data=10000
batch=100
set=100
layer=10
n_ini=1.0
n_fin=0.1
dn=-0.1
c_reg1=0.06
c_reg2=0.0003
d=4

# %%
def F_func(m, la, a,b):
    return 2*b/n_fin-m*a-la*(a**3)

def t_func(a):
    return 0.5*(tf.math.tanh(100*(a-0.1))-tf.math.tanh(100*(a+0.1))+2)

# %% [markdown]
# # Initial condition

# %%
h=tf.zeros(layer)
h_in=[]
for i in range (layer):
    h_inn=np.float64(np.random.normal(2, 1))
    h_in.append(h_inn)
h=tf.Variable(h_in)
m2=tf.Variable(np.float64(np.random.normal(2, 1)))
lam=tf.Variable(np.float64(np.random.normal(1, 1)))
alpha=tf.Variable(np.float64(np.random.uniform(-0.5, 0.5)))
beta=tf.Variable(np.float64(np.random.uniform(-0.5, 0.5)))
print("m^2=", m2)
print("lam=", lam)
print("alpha=", alpha)
print("beta=", beta)
print(h)
plt.plot(h.numpy(), 'k-')
plt.show()
# Out:
# m^2= <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=0.9604875910461785>
# lam= <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=-0.05973335875457364>
# alpha= <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=-0.47521032712681155>
# beta= <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=-0.004787354804241861>
# <tf.Variable 'Variable:0' shape=(10,) dtype=float64, numpy=
# array([0.34945951, 0.94127528, 1.91604137, 2.40591874, 2.07077523,
#        1.53593391, 2.26858079, 1.55936086, 1.32594978, 1.89388341])>

# %% [markdown]
# # Data generation

# %%
x=[i*0.2 for i in range (30)]
y=[0.0, 0.018, 0.035, 0.053, 0.0715, 0.0895, 0.107, 0.125, 0.146, 0.1665, 0.1875, 0.2085, 0.229, 0.25, 0.265, 0.281, 0.296, 0.3115, 0.3275, 0.343, 0.3565, 0.385, 0.4375, 0.5, 0.6, 0.675, 0.735, 0.815, 0.865, 0.885]
y[:]=[2*v for v in y]
fp1 = np.polyfit(x, y, 15)
print(fp1)
def f(x):
    y=0
    for i in range (16):
        y=y+fp1[i]*x**(15-i)
    return y
yy=[f(i*0.2) for i in range (30)]
plt.plot(x, y, 'r.')
plt.plot(x, yy, 'k-')
plt.show()
# Out:
# [ 1.59046380e-05 -6.81729619e-04  1.31412783e-02 -1.50525122e-01
#   1.14052764e+00 -6.02241589e+00  2.27455146e+01 -6.20704637e+01
#   1.22166909e+02 -1.71187057e+02  1.66428939e+02 -1.07461541e+02
#   4.28229849e+01 -9.20544844e+00  9.55260214e-01 -1.30925094e-04]

# %%
def NN_func_p(f):
    Positive=[]
    append=Positive.append
    while len(Positive)<batch:
        H=np.random.uniform(0.0, 6.0)
        M=np.random.uniform(0.0, 2.0)
        noise=np.abs(np.random.normal(0, 0.1))
        if np.abs(M-f(H))<=noise: append([H, M])
        else: continue
    return Positive
def NN_func_n(f):
    Negative=[]
    append=Negative.append
    while len(Negative)<batch:
        H=np.random.uniform(0.0, 6.0)
        M=np.random.uniform(0.0, 2.0)
        noise=np.abs(np.random.normal(0, 0.1))
        if np.abs(M-f(H))>noise: append([H, M])
        else: continue
    return Negative
def Dfunc(hh, m):
    D=tf.math.sqrt(tf.math.abs(1+4*m/(hh[0]**2)))
    return D

# %%
Positive=[]
Negative=[]
for i in range (set):
    Positive.insert(i, NN_func_p(f))
    Negative.insert(i, NN_func_n(f))
x_data1=[]
y_data1=[]
x_data2=[]
y_data2=[]
for i in range (set):
    x_data1.insert(i, [v[0] for v in Positive[i]])
    y_data1.insert(i, [v[1] for v in Positive[i]])
    x_data2.insert(i, [v[0] for v in Negative[i]])
    y_data2.insert(i, [v[1] for v in Negative[i]])
    plt.plot(x_data2[i], y_data2[i], 'y.')
    plt.plot(x_data1[i], y_data1[i], 'b.')
plt.show()

# %%
def LP2(hh, m, la, alpha, beta, HH, MM):
    D=Dfunc(hh, m)
    phi=alpha*HH+beta*MM
    pi=(d/2)*(D-1)*alpha*HH+(d/2)*(-D-1)*beta*MM
    for j in range (layer-1):
        phi1=phi+dn*pi
        pi1 =phi*m*dn+(1-dn*hh[j])*pi+dn*la*(phi1**3)
        phi=phi1
        pi=pi1
    return phi, pi
def NN_func_01(hh, m, la, alpha, beta, list_hr):
    PP=[]
    NN=[]
    H=np.array(list_hr)[:, 0]
    M=np.array(list_hr)[:, 1]
    F=np.array(tf.math.abs(LP2(hh, m, la, alpha, beta, H, M)[1]))
    for i in range (len(H[F<0.1])):
        PP.append([H[F<0.1][i], M[F<0.1][i]])
    for i in range (len(H[F>=0.1])):
        NN.append([H[F>=0.1][i], M[F>=0.1][i]])
    return PP, NN

# %%
Positive0=[]
Positive1=[]
Negative0=[]
Negative1=[]
for i in range (set):
    Positive0.insert(i, NN_func_01(h, m2, lam, alpha, beta, Positive[i])[0])
    Positive1.insert(i, NN_func_01(h, m2, lam, alpha, beta, Positive[i])[1])
    Negative0.insert(i, NN_func_01(h, m2, lam, alpha, beta, Negative[i])[0])
    Negative1.insert(i, NN_func_01(h, m2, lam, alpha, beta, Negative[i])[1])
x_data1=[]
y_data1=[]
x_data2=[]
y_data2=[]
x_data3=[]
y_data3=[]
x_data4=[]
y_data4=[]
for i in range (set):
    x_data1.insert(i, [v[0] for v in Positive0[i]])
    y_data1.insert(i, [v[1] for v in Positive0[i]])
    x_data2.insert(i, [v[0] for v in Positive1[i]])
    y_data2.insert(i, [v[1] for v in Positive1[i]])
    x_data3.insert(i, [v[0] for v in Negative0[i]])
    y_data3.insert(i, [v[1] for v in Negative0[i]])
    x_data4.insert(i, [v[0] for v in Negative1[i]])
    y_data4.insert(i, [v[1] for v in Negative1[i]])
    plt.plot(x_data4[i], y_data4[i], 'g.')
    plt.plot(x_data2[i], y_data2[i], 'c.')
    plt.plot(x_data1[i], y_data1[i], 'r.')
    plt.plot(x_data3[i], y_data3[i], 'm.')
plt.show()

# %% [markdown]
# # Error function

# %% [markdown]
# $E=\sum_{data} \left\vert y(\bar{x}^{(1)}) - \bar{y} \right\vert+E_{reg}(W)$
# , $E_{reg}=c_{reg}^{(1)}\sum_{n=1}^{N-1}(\eta^{(n)})^{4}(h(\eta^{(n+1)})-h(\eta^{(n)}))^{2}+c_{reg}^{(2)}(h(\eta^{(N)})-1/\eta^{(N)})^{2}$

# %%
def Error_func(hh, m, la, alpha, beta, list1, list2):
    H0=np.array([v[0] for v in list1])
    M0=np.array([v[1] for v in list1])
    H1=np.array([v[0] for v in list2])
    M1=np.array([v[1] for v in list2])
    H_0, M_0=LP2(hh, m, la, alpha, beta, H0, M0)
    H_1, M_1=LP2(hh, m, la, alpha, beta, H1, M1)
    PPlist=t_func(M_0)
    NNlist=t_func(M_1)
    sum_p=sum(PPlist)/batch
    sum_n=(batch-sum(NNlist))/batch

    inside=0
    for k in range (layer-1):
        second=((n_ini+k*dn)**4)*((hh[k+1]-hh[k])**2)
        inside=inside+second
    E_reg1=c_reg1*inside
    E_reg2=c_reg2*((hh[layer-1]-1/n_fin)**2)
    return sum_n+sum_p+E_reg1+E_reg2

# %%
for i in range (set):
    print(Error_func(h, m2, lam, alpha, beta, Positive[i], Negative[i]))
# Out:
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.1007040623054722, shape=(), dtype=float64)
# tf.Tensor(1.099583257258312, shape=(), dtype=float64)
# tf.Tensor(1.0907965490005784, shape=(), dtype=float64)
# tf.Tensor(1.100696725562806, shape=(), dtype=float64)
# tf.Tensor(1.0722638015961072, shape=(), dtype=float64)
# tf.Tensor(1.1007150417501803, shape=(), dtype=float64)
# tf.Tensor(1.1006545564258086, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.090714983833017, shape=(), dtype=float64)
# tf.Tensor(1.0907140277233736, shape=(), dtype=float64)
# tf.Tensor(1.09768703440557, shape=(), dtype=float64)
# tf.Tensor(1.0910851487331223, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.1007149785778774, shape=(), dtype=float64)
# tf.Tensor(1.0894790846091253, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.0907149785789074, shape=(), dtype=float64)
# tf.Tensor(1.0907152891312237, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.0807149851602724, shape=(), dtype=float64)
# tf.Tensor(1.1007127629552222, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.0895125813868833, shape=(), dtype=float64)
# tf.Tensor(1.0907149838316785, shape=(), dtype=float64)
# tf.Tensor(1.0907150003722217, shape=(), dtype=float64)
# tf.Tensor(1.0907149838329815, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.0907146935536334, shape=(), dtype=float64)
# tf.Tensor(1.1107131208083305, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.100714983756507, shape=(), dtype=float64)
# tf.Tensor(1.0907183374390095, shape=(), dtype=float64)
# tf.Tensor(1.0810054564905198, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.1006523105070731, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.1006916726439515, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.083332268367025, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.1007155206301191, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.08071498393231, shape=(), dtype=float64)
# tf.Tensor(1.1203579006055797, shape=(), dtype=float64)
# tf.Tensor(1.0907149701584595, shape=(), dtype=float64)
# tf.Tensor(1.0907149888485068, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.1007065992237797, shape=(), dtype=float64)
# tf.Tensor(1.1005902474588445, shape=(), dtype=float64)
# tf.Tensor(1.0907149838749062, shape=(), dtype=float64)
# tf.Tensor(1.090715182058553, shape=(), dtype=float64)
# tf.Tensor(1.0807149938355474, shape=(), dtype=float64)
# tf.Tensor(1.0999043988454682, shape=(), dtype=float64)
# tf.Tensor(1.0907388786134136, shape=(), dtype=float64)
# tf.Tensor(1.0907151224235108, shape=(), dtype=float64)
# tf.Tensor(1.0707152223381777, shape=(), dtype=float64)
# tf.Tensor(1.090714984020495, shape=(), dtype=float64)
# tf.Tensor(1.0907149838336467, shape=(), dtype=float64)
# tf.Tensor(1.1007115860409082, shape=(), dtype=float64)
# tf.Tensor(1.0907155423259818, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.1016675181553781, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.0952876423316695, shape=(), dtype=float64)
# tf.Tensor(1.080715026789513, shape=(), dtype=float64)
# tf.Tensor(1.0907256176077684, shape=(), dtype=float64)
# tf.Tensor(1.1004975924957963, shape=(), dtype=float64)
# tf.Tensor(1.090794178901854, shape=(), dtype=float64)
# tf.Tensor(1.0907149839881027, shape=(), dtype=float64)
# tf.Tensor(1.1007116983913305, shape=(), dtype=float64)
# tf.Tensor(1.1007482600057372, shape=(), dtype=float64)
# tf.Tensor(1.0965636349586947, shape=(), dtype=float64)
# tf.Tensor(1.1007149906738278, shape=(), dtype=float64)
# tf.Tensor(1.0807152233446002, shape=(), dtype=float64)
# tf.Tensor(1.090714983854086, shape=(), dtype=float64)
# tf.Tensor(1.0929941812647157, shape=(), dtype=float64)
# tf.Tensor(1.080789961156957, shape=(), dtype=float64)
# tf.Tensor(1.0907149838361785, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.0906038621827803, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.090714983832981, shape=(), dtype=float64)
# tf.Tensor(1.1007164247918482, shape=(), dtype=float64)
# tf.Tensor(1.0906966237881703, shape=(), dtype=float64)
# tf.Tensor(1.1107069273920502, shape=(), dtype=float64)
# tf.Tensor(1.0918949213164533, shape=(), dtype=float64)
# tf.Tensor(1.0807145668616138, shape=(), dtype=float64)
# tf.Tensor(1.0907149424765463, shape=(), dtype=float64)
# tf.Tensor(1.0974599416989808, shape=(), dtype=float64)
# tf.Tensor(1.0807120134020929, shape=(), dtype=float64)
# tf.Tensor(1.0933353254107256, shape=(), dtype=float64)
# tf.Tensor(1.100714963973025, shape=(), dtype=float64)
# tf.Tensor(1.0811744789858273, shape=(), dtype=float64)

# %% [markdown]
# # Optimize

# %%
optimizer=tf.optimizers.Adam(learning_rate=0.0005)
for j in range (10000):    
    with tf.GradientTape() as g:
        loss=Error_func(h, m2, lam, alpha, beta, Positive[j%set], Negative[j%set])
        gradients=g.gradient(loss, [h, m2, lam, alpha, beta])
        if np.isnan(loss)==True: break
    for i in range (90):
        optimizer.apply_gradients(zip(gradients, [h]))
        if any(np.isnan(h.numpy()))==True: break
    for i in range (10):
        optimizer.apply_gradients(zip(gradients, [h, m2, lam, alpha, beta]))
        if any(np.isnan(h.numpy()))==True: break
    if j%100==0: 
        print(j*10, Error_func(h, m2, lam, alpha, beta, Positive[np.int32((j/set)%set)], Negative[np.int32((j/set)%set)]).numpy())
        print(m2.numpy(), lam.numpy(), alpha.numpy(), beta.numpy()), print(h.numpy())
        plt.plot(h.numpy(), 'k-'), plt.show()
    if j%1000==0:
        for i in range (set):
            [Positive0[i], Positive1[i]]=NN_func_01(h, m2, lam, alpha, beta, Positive[i])
            [Negative0[i], Negative1[i]]=NN_func_01(h, m2, lam, alpha, beta, Negative[i])
        for i in range (set):
            x_data1[i]=[v[0] for v in Positive0[i]]
            y_data1[i]=[v[1] for v in Positive0[i]]
            x_data2[i]=[v[0] for v in Positive1[i]]
            y_data2[i]=[v[1] for v in Positive1[i]]
            x_data3[i]=[v[0] for v in Negative0[i]]
            y_data3[i]=[v[1] for v in Negative0[i]]
            x_data4[i]=[v[0] for v in Negative1[i]]
            y_data4[i]=[v[1] for v in Negative1[i]]
            plt.plot(x_data4[i], y_data4[i], 'g.')
            plt.plot(x_data2[i], y_data2[i], 'c.')
            plt.plot(x_data1[i], y_data1[i], 'r.')
            plt.plot(x_data3[i], y_data3[i], 'm.')
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
optimizer=tf.optimizers.Adam(learning_rate=0.0005)
for j in range (10000):    
    with tf.GradientTape() as g:
        loss=Error_func(h, m2, lam, alpha, beta, Positive[j%set], Negative[j%set])
        gradients=g.gradient(loss, [h, m2, lam, alpha, beta])
        if np.isnan(loss)==True: break
    for i in range (90):
        optimizer.apply_gradients(zip(gradients, [h]))
        if any(np.isnan(h.numpy()))==True: break
    for i in range (10):
        optimizer.apply_gradients(zip(gradients, [h, m2, lam, alpha, beta]))
        if any(np.isnan(h.numpy()))==True: break
    if j%100==0: 
        print(j*10, Error_func(h, m2, lam, alpha, beta, Positive[np.int32((j/set)%set)], Negative[np.int32((j/set)%set)]).numpy())
        print(m2.numpy(), lam.numpy(), alpha.numpy(), beta.numpy()), print(h.numpy())
        plt.plot(h.numpy(), 'k-'), plt.show()
    if j%1000==0:
        for i in range (set):
            [Positive0[i], Positive1[i]]=NN_func_01(h, m2, lam, alpha, beta, Positive[i])
            [Negative0[i], Negative1[i]]=NN_func_01(h, m2, lam, alpha, beta, Negative[i])
        for i in range (set):
            x_data1[i]=[v[0] for v in Positive0[i]]
            y_data1[i]=[v[1] for v in Positive0[i]]
            x_data2[i]=[v[0] for v in Positive1[i]]
            y_data2[i]=[v[1] for v in Positive1[i]]
            x_data3[i]=[v[0] for v in Negative0[i]]
            y_data3[i]=[v[1] for v in Negative0[i]]
            x_data4[i]=[v[0] for v in Negative1[i]]
            y_data4[i]=[v[1] for v in Negative1[i]]
            plt.plot(x_data4[i], y_data4[i], 'g.')
            plt.plot(x_data2[i], y_data2[i], 'c.')
            plt.plot(x_data1[i], y_data1[i], 'r.')
            plt.plot(x_data3[i], y_data3[i], 'm.')
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range (set):
    [Positive0[i], Positive1[i]]=NN_func_01(h, m2, lam, alpha, beta, Positive[i])
    [Negative0[i], Negative1[i]]=NN_func_01(h, m2, lam, alpha, beta, Negative[i])
for i in range (set):
    x_data1[i]=[v[0] for v in Positive0[i]]
    y_data1[i]=[v[1] for v in Positive0[i]]
    x_data2[i]=[v[0] for v in Positive1[i]]
    y_data2[i]=[v[1] for v in Positive1[i]]
    x_data3[i]=[v[0] for v in Negative0[i]]
    y_data3[i]=[v[1] for v in Negative0[i]]
    x_data4[i]=[v[0] for v in Negative1[i]]
    y_data4[i]=[v[1] for v in Negative1[i]]
    plt.plot(x_data4[i], y_data4[i], 'g.')
    plt.plot(x_data2[i], y_data2[i], 'c.')
    plt.plot(x_data1[i], y_data1[i], 'r.')
    plt.plot(x_data3[i], y_data3[i], 'm.')
plt.show()

# %%
print(j*10, Error_func(h, m2, lam, alpha, beta, Positive[np.int32((j/set)%set)], Negative[np.int32((j/set)%set)]).numpy())
print(m2.numpy(), lam.numpy(), alpha.numpy(), beta.numpy()), print(h.numpy())
plt.plot(h.numpy(), 'k-'), plt.show()
# Out:
# 99990 0.23111825942374686
# 0.16341457281108282 -0.26172861490781646 -0.1922652516372086 -0.07447775242123637
# [ 1.25315872  1.20952478  1.14143408  1.04737628  0.86047562  0.56614861
#   0.13278527 -0.46133545 -0.66289696  7.41643696]
# ([<matplotlib.lines.Line2D at 0x7fb3cf94e0b8>], None)
