# %% [markdown]
# # Intro

# %%
# !pip install tensorflow==2.0.0-rc1
# Out:
# Collecting tensorflow==2.0.0-rc1
#   Downloading https://files.pythonhosted.org/packages/40/d0/7359227ccfb6e2ae2a8fe345db1d513f010282022a7a6a899530cc63c41f/tensorflow-2.0.0rc1-cp36-cp36m-manylinux2010_x86_64.whl (86.3MB)
#      |████████████████████████████████| 86.3MB 53kB/s
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (0.2.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (3.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (0.9.0)
# Collecting tf-estimator-nightly<1.14.0.dev2019080602,>=1.14.0.dev2019080601
#   Downloading https://files.pythonhosted.org/packages/21/28/f2a27a62943d5f041e4a6fd404b2d21cb7c59b2242a4e73b03d9ba166552/tf_estimator_nightly-1.14.0.dev2019080601-py2.py3-none-any.whl (501kB)
#      |████████████████████████████████| 501kB 57.9MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (1.11.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (0.1.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (3.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (0.8.1)
# Collecting tb-nightly<1.15.0a20190807,>=1.15.0a20190806
#   Downloading https://files.pythonhosted.org/packages/bc/88/24b5fb7280e74c7cf65bde47c171547fd02afb3840cff41bcbe9270650f5/tb_nightly-1.15.0a20190806-py3-none-any.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 43.6MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (1.27.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (0.34.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (1.17.5)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0.0-rc1) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==2.0.0-rc1) (45.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc1) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc1) (1.0.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==2.0.0-rc1) (2.8.0)
# Installing collected packages: tf-estimator-nightly, tb-nightly, tensorflow
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# Successfully installed tb-nightly-1.15.0a20190806 tensorflow-2.0.0rc1 tf-estimator-nightly-1.14.0.dev2019080601

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math
print(tf.__version__)
# Out:
# 2.0.0-rc1

# %%
def coth(a):
    if a>0: return (1+tf.math.exp(-2*a))/(1-tf.math.exp(-2*a))
    if a<0: return (tf.math.exp(2*a)+1)/(tf.math.exp(2*a)-1)
    if a==0: return 0

def tanh(a):
    if a>0: return (1-tf.math.exp(-2*a))/(1+tf.math.exp(-2*a))
    if a<0: return (tf.math.exp(2*a)-1)/(tf.math.exp(2*a)+1)
    if a==0: return 0

# %%
data=10000
batch=100
set=100
layer=10
n_ini=1.0
n_fin=0.1
dn=-0.1
c_reg1=0.06
c_reg2=0.0003
d=4

# %%
def F_func(m, la, a,b):
    return 2*b/n_fin-m*a-la*(a**3)

def t_func(a):
    return 0.5*(tf.math.tanh(100*(a-0.1))-tf.math.tanh(100*(a+0.1))+2)

# %% [markdown]
# # Initial condition

# %%
h=tf.zeros(layer)
h_in=[]
for i in range (layer):
    h_inn=np.float64(np.random.normal(2, 1))
    h_in.append(h_inn)
h=tf.Variable(h_in)
m2=tf.Variable(np.float64(np.random.normal(2, 1)))
lam=tf.Variable(np.float64(np.random.normal(1, 1)))
alpha=tf.Variable(np.float64(np.random.uniform(-0.5, 0.5)))
beta=tf.Variable(np.float64(np.random.uniform(-0.5, 0.5)))
print("m^2=", m2)
print("lam=", lam)
print("alpha=", alpha)
print("beta=", beta)
print(h)
plt.plot(h.numpy(), 'k-')
plt.show()
# Out:
# m^2= <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=3.135521977894485>
# lam= <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=1.4466055272270468>
# alpha= <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=0.29832228517775927>
# beta= <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=0.2547474771094288>
# <tf.Variable 'Variable:0' shape=(10,) dtype=float64, numpy=
# array([ 4.53029742,  2.18203506,  0.93157529,  1.96112395,  3.28234601,
#        -0.16878301,  0.83407037,  3.29481437,  2.59957279,  2.7766114 ])>

# %% [markdown]
# # Data generation

# %%
x=[i*0.2 for i in range (30)]
y=[0.0, 0.018, 0.035, 0.053, 0.0715, 0.0895, 0.107, 0.125, 0.146, 0.1665, 0.1875, 0.2085, 0.229, 0.25, 0.265, 0.281, 0.296, 0.3115, 0.3275, 0.343, 0.3565, 0.385, 0.4375, 0.5, 0.6, 0.675, 0.735, 0.815, 0.865, 0.885]
y[:]=[2*v for v in y]
fp1 = np.polyfit(x, y, 15)
print(fp1)
def f(x):
    y=0
    for i in range (16):
        y=y+fp1[i]*x**(15-i)
    return y
yy=[f(i*0.2) for i in range (30)]
plt.plot(x, y, 'r.')
plt.plot(x, yy, 'k-')
plt.show()
# Out:
# [ 1.59046380e-05 -6.81729619e-04  1.31412783e-02 -1.50525122e-01
#   1.14052764e+00 -6.02241589e+00  2.27455146e+01 -6.20704637e+01
#   1.22166909e+02 -1.71187057e+02  1.66428939e+02 -1.07461541e+02
#   4.28229849e+01 -9.20544844e+00  9.55260214e-01 -1.30925094e-04]

# %%
def NN_func_p(f):
    Positive=[]
    append=Positive.append
    while len(Positive)<batch:
        H=np.random.uniform(0.0, 6.0)
        M=np.random.uniform(0.0, 2.0)
        noise=np.abs(np.random.normal(0, 0.1))
        if np.abs(M-f(H))<=noise: append([H, M])
        else: continue
    return Positive
def NN_func_n(f):
    Negative=[]
    append=Negative.append
    while len(Negative)<batch:
        H=np.random.uniform(0.0, 6.0)
        M=np.random.uniform(0.0, 2.0)
        noise=np.abs(np.random.normal(0, 0.1))
        if np.abs(M-f(H))>noise: append([H, M])
        else: continue
    return Negative
def Dfunc(hh, m):
    D=tf.math.sqrt(tf.math.abs(1+4*m/(hh[0]**2)))
    return D

# %%
Positive=[]
Negative=[]
for i in range (set):
    Positive.insert(i, NN_func_p(f))
    Negative.insert(i, NN_func_n(f))
x_data1=[]
y_data1=[]
x_data2=[]
y_data2=[]
for i in range (set):
    x_data1.insert(i, [v[0] for v in Positive[i]])
    y_data1.insert(i, [v[1] for v in Positive[i]])
    x_data2.insert(i, [v[0] for v in Negative[i]])
    y_data2.insert(i, [v[1] for v in Negative[i]])
    plt.plot(x_data2[i], y_data2[i], 'y.')
    plt.plot(x_data1[i], y_data1[i], 'b.')
plt.show()

# %%
def LP2(hh, m, la, alpha, beta, HH, MM):
    D=Dfunc(hh, m)
    phi=alpha*HH+beta*MM
    pi=(d/2)*(D-1)*alpha*HH+(d/2)*(-D-1)*beta*MM
    for j in range (layer-1):
        phi1=phi+dn*pi
        pi1 =phi*m*dn+(1-dn*hh[j])*pi+dn*la*(phi1**3)
        phi=phi1
        pi=pi1
    return phi, pi
def NN_func_01(hh, m, la, alpha, beta, list_hr):
    PP=[]
    NN=[]
    H=np.array(list_hr)[:, 0]
    M=np.array(list_hr)[:, 1]
    F=np.array(tf.math.abs(LP2(hh, m, la, alpha, beta, H, M)[1]))
    for i in range (len(H[F<0.1])):
        PP.append([H[F<0.1][i], M[F<0.1][i]])
    for i in range (len(H[F>=0.1])):
        NN.append([H[F>=0.1][i], M[F>=0.1][i]])
    return PP, NN

# %%
Positive0=[]
Positive1=[]
Negative0=[]
Negative1=[]
for i in range (set):
    Positive0.insert(i, NN_func_01(h, m2, lam, alpha, beta, Positive[i])[0])
    Positive1.insert(i, NN_func_01(h, m2, lam, alpha, beta, Positive[i])[1])
    Negative0.insert(i, NN_func_01(h, m2, lam, alpha, beta, Negative[i])[0])
    Negative1.insert(i, NN_func_01(h, m2, lam, alpha, beta, Negative[i])[1])
x_data1=[]
y_data1=[]
x_data2=[]
y_data2=[]
x_data3=[]
y_data3=[]
x_data4=[]
y_data4=[]
for i in range (set):
    x_data1.insert(i, [v[0] for v in Positive0[i]])
    y_data1.insert(i, [v[1] for v in Positive0[i]])
    x_data2.insert(i, [v[0] for v in Positive1[i]])
    y_data2.insert(i, [v[1] for v in Positive1[i]])
    x_data3.insert(i, [v[0] for v in Negative0[i]])
    y_data3.insert(i, [v[1] for v in Negative0[i]])
    x_data4.insert(i, [v[0] for v in Negative1[i]])
    y_data4.insert(i, [v[1] for v in Negative1[i]])
    plt.plot(x_data4[i], y_data4[i], 'g.')
    plt.plot(x_data2[i], y_data2[i], 'c.')
    plt.plot(x_data1[i], y_data1[i], 'r.')
    plt.plot(x_data3[i], y_data3[i], 'm.')
plt.show()

# %% [markdown]
# # Error function

# %% [markdown]
# $E=\sum_{data} \left\vert y(\bar{x}^{(1)}) - \bar{y} \right\vert+E_{reg}(W)$
# , $E_{reg}=c_{reg}^{(1)}\sum_{n=1}^{N-1}(\eta^{(n)})^{4}(h(\eta^{(n+1)})-h(\eta^{(n)}))^{2}+c_{reg}^{(2)}(h(\eta^{(N)})-1/\eta^{(N)})^{2}$

# %%
def Error_func(hh, m, la, alpha, beta, list1, list2):
    H0=np.array([v[0] for v in list1])
    M0=np.array([v[1] for v in list1])
    H1=np.array([v[0] for v in list2])
    M1=np.array([v[1] for v in list2])
    H_0, M_0=LP2(hh, m, la, alpha, beta, H0, M0)
    H_1, M_1=LP2(hh, m, la, alpha, beta, H1, M1)
    PPlist=t_func(M_0)**2
    NNlist=(1-t_func(M_1))**2
    sum_p=sum(PPlist)/batch
    sum_n=sum(NNlist)/batch

    inside=0
    for k in range (layer-1):
        second=((n_ini+k*dn)**4)*((hh[k+1]-hh[k])**2)
        inside=inside+second
    E_reg1=c_reg1*inside
    E_reg2=c_reg2*((hh[layer-1]-1/n_fin)**2)
    return sum_n+sum_p+E_reg1+E_reg2

# %%
for i in range (set):
    print(Error_func(h, m2, lam, alpha, beta, Positive[i], Negative[i]))
# Out:
# tf.Tensor(1.6780321056519294, shape=(), dtype=float64)
# tf.Tensor(1.6377234325209742, shape=(), dtype=float64)
# tf.Tensor(1.636829071189996, shape=(), dtype=float64)
# tf.Tensor(1.6287600733291272, shape=(), dtype=float64)
# tf.Tensor(1.6412148001372338, shape=(), dtype=float64)
# tf.Tensor(1.6499423769547703, shape=(), dtype=float64)
# tf.Tensor(1.6416199313344215, shape=(), dtype=float64)
# tf.Tensor(1.6556238322985402, shape=(), dtype=float64)
# tf.Tensor(1.6878742624844405, shape=(), dtype=float64)
# tf.Tensor(1.6673914495622795, shape=(), dtype=float64)
# tf.Tensor(1.6581486970886408, shape=(), dtype=float64)
# tf.Tensor(1.678042087170771, shape=(), dtype=float64)
# tf.Tensor(1.6358835564141259, shape=(), dtype=float64)
# tf.Tensor(1.6777593443235856, shape=(), dtype=float64)
# tf.Tensor(1.6738328085803806, shape=(), dtype=float64)
# tf.Tensor(1.6552051188981467, shape=(), dtype=float64)
# tf.Tensor(1.6579413821063116, shape=(), dtype=float64)
# tf.Tensor(1.657968288165204, shape=(), dtype=float64)
# tf.Tensor(1.6765758485261975, shape=(), dtype=float64)
# tf.Tensor(1.656178896174842, shape=(), dtype=float64)
# tf.Tensor(1.660131392201929, shape=(), dtype=float64)
# tf.Tensor(1.6780287763197554, shape=(), dtype=float64)
# tf.Tensor(1.664904113102919, shape=(), dtype=float64)
# tf.Tensor(1.6380403008064677, shape=(), dtype=float64)
# tf.Tensor(1.6598995383938075, shape=(), dtype=float64)
# tf.Tensor(1.637948714271685, shape=(), dtype=float64)
# tf.Tensor(1.658040152692903, shape=(), dtype=float64)
# tf.Tensor(1.6569352754344213, shape=(), dtype=float64)
# tf.Tensor(1.6480426672349826, shape=(), dtype=float64)
# tf.Tensor(1.6781224865251523, shape=(), dtype=float64)
# tf.Tensor(1.6777199366444044, shape=(), dtype=float64)
# tf.Tensor(1.6480940171290168, shape=(), dtype=float64)
# tf.Tensor(1.6684578770941982, shape=(), dtype=float64)
# tf.Tensor(1.677919057630683, shape=(), dtype=float64)
# tf.Tensor(1.668059529694275, shape=(), dtype=float64)
# tf.Tensor(1.6579664720492011, shape=(), dtype=float64)
# tf.Tensor(1.669815170319041, shape=(), dtype=float64)
# tf.Tensor(1.6584083978118889, shape=(), dtype=float64)
# tf.Tensor(1.6849565948345904, shape=(), dtype=float64)
# tf.Tensor(1.6739326621785495, shape=(), dtype=float64)
# tf.Tensor(1.640574225493376, shape=(), dtype=float64)
# tf.Tensor(1.587062736619267, shape=(), dtype=float64)
# tf.Tensor(1.641331914050201, shape=(), dtype=float64)
# tf.Tensor(1.655075369319157, shape=(), dtype=float64)
# tf.Tensor(1.6406175398638712, shape=(), dtype=float64)
# tf.Tensor(1.6780356417551618, shape=(), dtype=float64)
# tf.Tensor(1.6444467305315933, shape=(), dtype=float64)
# tf.Tensor(1.6762709678583252, shape=(), dtype=float64)
# tf.Tensor(1.6680453923632452, shape=(), dtype=float64)
# tf.Tensor(1.648750780275516, shape=(), dtype=float64)
# tf.Tensor(1.6284957189633529, shape=(), dtype=float64)
# tf.Tensor(1.6621042458616806, shape=(), dtype=float64)
# tf.Tensor(1.68757677614831, shape=(), dtype=float64)
# tf.Tensor(1.6557685096076555, shape=(), dtype=float64)
# tf.Tensor(1.6580748123339286, shape=(), dtype=float64)
# tf.Tensor(1.6745849125666394, shape=(), dtype=float64)
# tf.Tensor(1.6391843211893637, shape=(), dtype=float64)
# tf.Tensor(1.6280646423359406, shape=(), dtype=float64)
# tf.Tensor(1.6628624425399545, shape=(), dtype=float64)
# tf.Tensor(1.6587805404472473, shape=(), dtype=float64)
# tf.Tensor(1.6649110185118354, shape=(), dtype=float64)
# tf.Tensor(1.6877887373210483, shape=(), dtype=float64)
# tf.Tensor(1.60697342759988, shape=(), dtype=float64)
# tf.Tensor(1.628314158478527, shape=(), dtype=float64)
# tf.Tensor(1.6680659731819754, shape=(), dtype=float64)
# tf.Tensor(1.6579498421783345, shape=(), dtype=float64)
# tf.Tensor(1.658333711389068, shape=(), dtype=float64)
# tf.Tensor(1.6281625947238436, shape=(), dtype=float64)
# tf.Tensor(1.6716529624604644, shape=(), dtype=float64)
# tf.Tensor(1.667513566524604, shape=(), dtype=float64)
# tf.Tensor(1.6379854711751507, shape=(), dtype=float64)
# tf.Tensor(1.6458320006179665, shape=(), dtype=float64)
# tf.Tensor(1.6517883455595204, shape=(), dtype=float64)
# tf.Tensor(1.6582546411940529, shape=(), dtype=float64)
# tf.Tensor(1.6880425607481255, shape=(), dtype=float64)
# tf.Tensor(1.6763002950291657, shape=(), dtype=float64)
# tf.Tensor(1.6468293443213438, shape=(), dtype=float64)
# tf.Tensor(1.657900837697916, shape=(), dtype=float64)
# tf.Tensor(1.6372996137640112, shape=(), dtype=float64)
# tf.Tensor(1.649573547816417, shape=(), dtype=float64)
# tf.Tensor(1.6579718903813896, shape=(), dtype=float64)
# tf.Tensor(1.673704065384621, shape=(), dtype=float64)
# tf.Tensor(1.6756988402470268, shape=(), dtype=float64)
# tf.Tensor(1.6780404480400946, shape=(), dtype=float64)
# tf.Tensor(1.6608983312054497, shape=(), dtype=float64)
# tf.Tensor(1.6273665407607707, shape=(), dtype=float64)
# tf.Tensor(1.620093115932434, shape=(), dtype=float64)
# tf.Tensor(1.6450350141453405, shape=(), dtype=float64)
# tf.Tensor(1.638016998614167, shape=(), dtype=float64)
# tf.Tensor(1.6649280302792295, shape=(), dtype=float64)
# tf.Tensor(1.6633505527887538, shape=(), dtype=float64)
# tf.Tensor(1.6676945284179445, shape=(), dtype=float64)
# tf.Tensor(1.6880263830559326, shape=(), dtype=float64)
# tf.Tensor(1.6780094872696896, shape=(), dtype=float64)
# tf.Tensor(1.637780931434967, shape=(), dtype=float64)
# tf.Tensor(1.6261813527137696, shape=(), dtype=float64)
# tf.Tensor(1.6510076885028593, shape=(), dtype=float64)
# tf.Tensor(1.6771466981282217, shape=(), dtype=float64)
# tf.Tensor(1.6730135752752617, shape=(), dtype=float64)
# tf.Tensor(1.652905952760456, shape=(), dtype=float64)

# %% [markdown]
# # Optimize

# %%
optimizer=tf.optimizers.Adam(learning_rate=0.0005)
for j in range (10000):    
    with tf.GradientTape() as g:
        loss=Error_func(h, m2, lam, alpha, beta, Positive[j%set], Negative[j%set])
        gradients=g.gradient(loss, [h, m2, lam, alpha, beta])
        if np.isnan(loss)==True: break
    for i in range (90):
        optimizer.apply_gradients(zip(gradients, [h]))
        if any(np.isnan(h.numpy()))==True: break
    for i in range (10):
        optimizer.apply_gradients(zip(gradients, [h, m2, lam, alpha, beta]))
        if any(np.isnan(h.numpy()))==True: break
    if j%100==0: 
        print(j*10, Error_func(h, m2, lam, alpha, beta, Positive[np.int32((j/set)%set)], Negative[np.int32((j/set)%set)]).numpy())
        print(m2.numpy(), lam.numpy(), alpha.numpy(), beta.numpy()), print(h.numpy())
        plt.plot(h.numpy(), 'k-'), plt.show()
    if j%1000==0:
        for i in range (set):
            [Positive0[i], Positive1[i]]=NN_func_01(h, m2, lam, alpha, beta, Positive[i])
            [Negative0[i], Negative1[i]]=NN_func_01(h, m2, lam, alpha, beta, Negative[i])
        for i in range (set):
            x_data1[i]=[v[0] for v in Positive0[i]]
            y_data1[i]=[v[1] for v in Positive0[i]]
            x_data2[i]=[v[0] for v in Positive1[i]]
            y_data2[i]=[v[1] for v in Positive1[i]]
            x_data3[i]=[v[0] for v in Negative0[i]]
            y_data3[i]=[v[1] for v in Negative0[i]]
            x_data4[i]=[v[0] for v in Negative1[i]]
            y_data4[i]=[v[1] for v in Negative1[i]]
            plt.plot(x_data4[i], y_data4[i], 'g.')
            plt.plot(x_data2[i], y_data2[i], 'c.')
            plt.plot(x_data1[i], y_data1[i], 'r.')
            plt.plot(x_data3[i], y_data3[i], 'm.')
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
optimizer=tf.optimizers.Adam(learning_rate=0.0005)
for j in range (10000):    
    with tf.GradientTape() as g:
        loss=Error_func(h, m2, lam, alpha, beta, Positive[j%set], Negative[j%set])
        gradients=g.gradient(loss, [h, m2, lam, alpha, beta])
        if np.isnan(loss)==True: break
    for i in range (90):
        optimizer.apply_gradients(zip(gradients, [h]))
        if any(np.isnan(h.numpy()))==True: break
    for i in range (10):
        optimizer.apply_gradients(zip(gradients, [h, m2, lam, alpha, beta]))
        if any(np.isnan(h.numpy()))==True: break
    if j%100==0: 
        print(j*10, Error_func(h, m2, lam, alpha, beta, Positive[np.int32((j/set)%set)], Negative[np.int32((j/set)%set)]).numpy())
        print(m2.numpy(), lam.numpy(), alpha.numpy(), beta.numpy()), print(h.numpy())
        plt.plot(h.numpy(), 'k-'), plt.show()
    if j%1000==0:
        for i in range (set):
            [Positive0[i], Positive1[i]]=NN_func_01(h, m2, lam, alpha, beta, Positive[i])
            [Negative0[i], Negative1[i]]=NN_func_01(h, m2, lam, alpha, beta, Negative[i])
        for i in range (set):
            x_data1[i]=[v[0] for v in Positive0[i]]
            y_data1[i]=[v[1] for v in Positive0[i]]
            x_data2[i]=[v[0] for v in Positive1[i]]
            y_data2[i]=[v[1] for v in Positive1[i]]
            x_data3[i]=[v[0] for v in Negative0[i]]
            y_data3[i]=[v[1] for v in Negative0[i]]
            x_data4[i]=[v[0] for v in Negative1[i]]
            y_data4[i]=[v[1] for v in Negative1[i]]
            plt.plot(x_data4[i], y_data4[i], 'g.')
            plt.plot(x_data2[i], y_data2[i], 'c.')
            plt.plot(x_data1[i], y_data1[i], 'r.')
            plt.plot(x_data3[i], y_data3[i], 'm.')
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range (set):
    [Positive0[i], Positive1[i]]=NN_func_01(h, m2, lam, alpha, beta, Positive[i])
    [Negative0[i], Negative1[i]]=NN_func_01(h, m2, lam, alpha, beta, Negative[i])
for i in range (set):
    x_data1[i]=[v[0] for v in Positive0[i]]
    y_data1[i]=[v[1] for v in Positive0[i]]
    x_data2[i]=[v[0] for v in Positive1[i]]
    y_data2[i]=[v[1] for v in Positive1[i]]
    x_data3[i]=[v[0] for v in Negative0[i]]
    y_data3[i]=[v[1] for v in Negative0[i]]
    x_data4[i]=[v[0] for v in Negative1[i]]
    y_data4[i]=[v[1] for v in Negative1[i]]
    plt.plot(x_data4[i], y_data4[i], 'g.')
    plt.plot(x_data2[i], y_data2[i], 'c.')
    plt.plot(x_data1[i], y_data1[i], 'r.')
    plt.plot(x_data3[i], y_data3[i], 'm.')
plt.show()

# %%
print(j*10, Error_func(h, m2, lam, alpha, beta, Positive[np.int32((j/set)%set)], Negative[np.int32((j/set)%set)]).numpy())
print(m2.numpy(), lam.numpy(), alpha.numpy(), beta.numpy()), print(h.numpy())
plt.plot(h.numpy(), 'k-'), plt.show()
# Out:
# 99990 0.17009578552482874
# 0.19153946041056702 -0.4106792262266993 0.15365345837668626 0.07569676640661235
# [ 1.27704606  1.18205973  1.11118264  0.97932436  0.78091044  0.4989963
#   0.08505811 -0.46016229 -0.57112975  7.44753697]
# ([<matplotlib.lines.Line2D at 0x7f92a78676d8>], None)
